# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:**  About CNN-RNN Architecture : I have used a ResNet pre-trained model for the encoder. ResNet stands for Residual Networks. More specifically, I have used resnet-50 which is a 50 layer residual network. In order to get more glimpse about the ResNet architecture, follow this paper : https://arxiv.org/pdf/1512.03385.pdf . It has been proved that training residual networks is easier than training  a simple deep convolutional neural networks and also the problem of degrading accuracy is resolved in case of ResNets.
#
# The CNN encoder has been implemented with the final fully-connected layer removed to extract features from a batch of pre-processed images. The output is then flattened to a vector, before being passed through a Linear layer to transform the feature vector to have the same size as the word embedding.
#
# For Decoder, I have followed the Show and Tell Model described in this paper (https://arxiv.org/pdf/1411.4555.pdf). The structure includes a single LSTM  (Long Short Term Memory ) layer followed by a fully-connected (linear) layer.
#
# Tweaking of Hyperparameters: I have used a batch size of 25 which is enough to reduce the variance of the stochastic gradients. This, in turn, allows to take bigger step-sizes, which means the optimization algorithm makes progress faster. I have used a vocab_threshold value of 5. We need this parameter to be set for building the vocabulary file. With this value of voccab_threshold, vocabulary of 8855 tokens has been built. Also, I have used embed_size = 512 and hidden_size = 512.
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:** For the pre-trained CNN Encoder, we need a tensor of shape (224x224x3). So, in order to achieve this , I have transformed the image. I have first resized the original image to 256 and then getting it cropped to the size 224x224 from any random location. After that I have flipped the image horizontally with the probability of 0.5 and then finally converted the PIL image to a tensor and getting it normalized for a pre-trained CNN encoder.
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:** I have used the following trainable parameters for decoder and encoder respectively. { params = list(decoder.parameters()) + list(encoder.embed.parameters()) }. Since, the decoder is being trained from scratch so we need to train all the parameters . Hence, for decoder, I have taken all the learnable parameters (decoder.parameters()) . And, since we are using a pre-trained model for encoder, hence there is no need to take into account all the parameters. However, I do need the parameters of embedding layer to be trained. Hence, for encoder, I have used (encoder.embed.parameters()).
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:** Since Adam maintains an adaptive learning rate and momentum for each parameter so, I used Adam Optimizer with the following parameters:
#
#     learning rate: 0.001
#     betas: (0.9, 0.999) -> used for computing running averages of gradient and its square
#     eps: (1e-8) -> to improve numerical stablility
#
# Also, it follows per-parameter learning rate methods, which helps in tuning hyperparameters for the learning rate schedule without requiring expensive work. It is faster and outeperforms other techniques.

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 25          # batch size
vocab_threshold = 5        # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 512           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 3             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters())  + list(encoder.embed.parameters())

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params, lr=0.001, betas=(0.9, 0.999), eps=1e-08)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
#   0%|          | 1186/414113 [00:00<01:12, 5712.37it/s]
# Done (t=0.80s)
# creating index...
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [01:04<00:00, 6415.11it/s]

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
response = requests.request("GET", 
                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                            headers={"Metadata-Flavor":"Google"})

for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        if time.time() - old_time > 60:
            old_time = time.time()
            requests.request("POST", 
                             "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                             headers={'Authorization': "STAR " + response.text})
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Epoch [1/3], Step [100/16565], Loss: 4.5503, Perplexity: 94.65734
# Epoch [1/3], Step [200/16565], Loss: 3.5806, Perplexity: 35.89673
# Epoch [1/3], Step [300/16565], Loss: 3.5517, Perplexity: 34.87364
# Epoch [1/3], Step [400/16565], Loss: 3.5940, Perplexity: 36.3794
# Epoch [1/3], Step [500/16565], Loss: 3.1040, Perplexity: 22.2873
# Epoch [1/3], Step [600/16565], Loss: 2.9415, Perplexity: 18.9447
# Epoch [1/3], Step [700/16565], Loss: 3.0424, Perplexity: 20.9564
# Epoch [1/3], Step [1000/16565], Loss: 3.1911, Perplexity: 24.3141
# Epoch [1/3], Step [1100/16565], Loss: 2.9321, Perplexity: 18.7665
# Epoch [1/3], Step [1200/16565], Loss: 2.7328, Perplexity: 15.3761
# Epoch [1/3], Step [1300/16565], Loss: 2.7570, Perplexity: 15.7529
# Epoch [1/3], Step [1400/16565], Loss: 3.0571, Perplexity: 21.2663
# Epoch [1/3], Step [1500/16565], Loss: 2.6881, Perplexity: 14.7037
# Epoch [1/3], Step [1600/16565], Loss: 2.5019, Perplexity: 12.20589
# Epoch [1/3], Step [1700/16565], Loss: 2.8081, Perplexity: 16.5790
# Epoch [1/3], Step [1800/16565], Loss: 2.5812, Perplexity: 13.21251
# Epoch [1/3], Step [1900/16565], Loss: 2.5222, Perplexity: 12.4557
# Epoch [1/3], Step [2000/16565], Loss: 2.7092, Perplexity: 15.01728
# Epoch [1/3], Step [2100/16565], Loss: 2.8871, Perplexity: 17.9418
# Epoch [1/3], Step [2200/16565], Loss: 2.9717, Perplexity: 19.5250
# Epoch [1/3], Step [2300/16565], Loss: 2.4181, Perplexity: 11.2248
# Epoch [1/3], Step [2400/16565], Loss: 2.7997, Perplexity: 16.4404
# Epoch [1/3], Step [2500/16565], Loss: 2.9096, Perplexity: 18.3503
# Epoch [1/3], Step [2600/16565], Loss: 2.3759, Perplexity: 10.7604
# Epoch [1/3], Step [2700/16565], Loss: 2.8272, Perplexity: 16.8985
# Epoch [1/3], Step [2800/16565], Loss: 4.3998, Perplexity: 81.4361
# Epoch [1/3], Step [2900/16565], Loss: 3.1626, Perplexity: 23.6322
# Epoch [1/3], Step [3000/16565], Loss: 2.4795, Perplexity: 11.9352
# Epoch [1/3], Step [3100/16565], Loss: 2.6813, Perplexity: 14.6043
# Epoch [1/3], Step [3200/16565], Loss: 2.5964, Perplexity: 13.4157
# Epoch [1/3], Step [3300/16565], Loss: 2.5217, Perplexity: 12.4502
# Epoch [1/3], Step [3400/16565], Loss: 2.5144, Perplexity: 12.3597
# Epoch [1/3], Step [3500/16565], Loss: 2.4386, Perplexity: 11.4574
# Epoch [1/3], Step [3600/16565], Loss: 2.6094, Perplexity: 13.5913
# Epoch [1/3], Step [3700/16565], Loss: 2.4249, Perplexity: 11.3006
# Epoch [1/3], Step [3800/16565], Loss: 2.4826, Perplexity: 11.9721
# Epoch [1/3], Step [3900/16565], Loss: 2.5480, Perplexity: 12.7820
# Epoch [1/3], Step [4000/16565], Loss: 2.6325, Perplexity: 13.9087
# Epoch [1/3], Step [4100/16565], Loss: 2.2675, Perplexity: 9.65493
# Epoch [1/3], Step [4200/16565], Loss: 2.5043, Perplexity: 12.2352
# Epoch [1/3], Step [4300/16565], Loss: 2.2324, Perplexity: 9.32182
# Epoch [1/3], Step [4400/16565], Loss: 2.2620, Perplexity: 9.60198
# Epoch [1/3], Step [4500/16565], Loss: 2.2441, Perplexity: 9.43208
# Epoch [1/3], Step [4600/16565], Loss: 2.6212, Perplexity: 13.7522
# Epoch [1/3], Step [4700/16565], Loss: 2.5562, Perplexity: 12.8869
# Epoch [1/3], Step [4800/16565], Loss: 2.5798, Perplexity: 13.1938
# Epoch [1/3], Step [4900/16565], Loss: 2.3924, Perplexity: 10.9392
# Epoch [1/3], Step [5000/16565], Loss: 2.6818, Perplexity: 14.6111
# Epoch [1/3], Step [5100/16565], Loss: 2.7071, Perplexity: 14.9857
# Epoch [1/3], Step [5200/16565], Loss: 2.2990, Perplexity: 9.96459
# Epoch [1/3], Step [5300/16565], Loss: 2.4367, Perplexity: 11.4357
# Epoch [1/3], Step [5400/16565], Loss: 2.2276, Perplexity: 9.27724
# Epoch [1/3], Step [5500/16565], Loss: 2.5657, Perplexity: 13.0102
# Epoch [1/3], Step [5600/16565], Loss: 2.3359, Perplexity: 10.3387
# Epoch [1/3], Step [5700/16565], Loss: 2.4261, Perplexity: 11.3149
# Epoch [1/3], Step [5800/16565], Loss: 2.8116, Perplexity: 16.6357
# Epoch [1/3], Step [5900/16565], Loss: 2.4551, Perplexity: 11.6475
# Epoch [1/3], Step [6000/16565], Loss: 2.1072, Perplexity: 8.22494
# Epoch [1/3], Step [6100/16565], Loss: 2.5000, Perplexity: 12.1824
# Epoch [1/3], Step [6200/16565], Loss: 2.7017, Perplexity: 14.9055
# Epoch [1/3], Step [6300/16565], Loss: 2.9197, Perplexity: 18.5363
# Epoch [1/3], Step [6400/16565], Loss: 2.5580, Perplexity: 12.9106
# Epoch [1/3], Step [6500/16565], Loss: 2.1991, Perplexity: 9.01730
# Epoch [1/3], Step [6600/16565], Loss: 2.3756, Perplexity: 10.7578
# Epoch [1/3], Step [6700/16565], Loss: 2.5119, Perplexity: 12.3287
# Epoch [1/3], Step [6800/16565], Loss: 2.2024, Perplexity: 9.04716
# Epoch [1/3], Step [6900/16565], Loss: 2.1113, Perplexity: 8.25932
# Epoch [1/3], Step [7000/16565], Loss: 2.4160, Perplexity: 11.2005
# Epoch [1/3], Step [7100/16565], Loss: 2.3988, Perplexity: 11.0100
# Epoch [1/3], Step [7200/16565], Loss: 2.4608, Perplexity: 11.7145
# Epoch [1/3], Step [7300/16565], Loss: 2.7050, Perplexity: 14.9543
# Epoch [1/3], Step [7400/16565], Loss: 2.5659, Perplexity: 13.0120
# Epoch [1/3], Step [7500/16565], Loss: 3.0279, Perplexity: 20.6548
# Epoch [1/3], Step [7600/16565], Loss: 2.0860, Perplexity: 8.05291
# Epoch [1/3], Step [7700/16565], Loss: 2.1788, Perplexity: 8.83590
# Epoch [1/3], Step [8000/16565], Loss: 2.1782, Perplexity: 8.83053
# Epoch [1/3], Step [8100/16565], Loss: 2.1476, Perplexity: 8.56390
# Epoch [1/3], Step [8200/16565], Loss: 3.5989, Perplexity: 36.5574
# Epoch [1/3], Step [8300/16565], Loss: 2.8772, Perplexity: 17.7642
# Epoch [1/3], Step [8400/16565], Loss: 2.4212, Perplexity: 11.2595
# Epoch [1/3], Step [8500/16565], Loss: 2.6709, Perplexity: 14.4534
# Epoch [1/3], Step [8600/16565], Loss: 2.2701, Perplexity: 9.68004
# Epoch [1/3], Step [8700/16565], Loss: 2.3931, Perplexity: 10.9479
# Epoch [1/3], Step [8800/16565], Loss: 2.0960, Perplexity: 8.13380
# Epoch [1/3], Step [8900/16565], Loss: 2.2260, Perplexity: 9.26240
# Epoch [1/3], Step [9000/16565], Loss: 2.3392, Perplexity: 10.3725
# Epoch [1/3], Step [9100/16565], Loss: 2.4293, Perplexity: 11.3511
# Epoch [1/3], Step [9200/16565], Loss: 2.6748, Perplexity: 14.5100
# Epoch [1/3], Step [9300/16565], Loss: 1.9623, Perplexity: 7.11544
# Epoch [1/3], Step [9400/16565], Loss: 2.3251, Perplexity: 10.2275
# Epoch [1/3], Step [9500/16565], Loss: 2.2929, Perplexity: 9.90323
# Epoch [1/3], Step [9600/16565], Loss: 2.2805, Perplexity: 9.78177
# Epoch [1/3], Step [9700/16565], Loss: 2.0828, Perplexity: 8.02685
# Epoch [1/3], Step [9800/16565], Loss: 2.2777, Perplexity: 9.75410
# Epoch [1/3], Step [9900/16565], Loss: 2.1633, Perplexity: 8.70010
# Epoch [1/3], Step [10000/16565], Loss: 2.1296, Perplexity: 8.4115
# Epoch [1/3], Step [10100/16565], Loss: 2.4433, Perplexity: 11.5113
# Epoch [1/3], Step [10200/16565], Loss: 2.2799, Perplexity: 9.77568
# Epoch [1/3], Step [10300/16565], Loss: 2.9143, Perplexity: 18.4366
# Epoch [1/3], Step [10400/16565], Loss: 2.4949, Perplexity: 12.1203
# Epoch [1/3], Step [10500/16565], Loss: 2.3574, Perplexity: 10.5638
# Epoch [1/3], Step [10600/16565], Loss: 2.2146, Perplexity: 9.15806
# Epoch [1/3], Step [10700/16565], Loss: 2.3892, Perplexity: 10.9047
# Epoch [1/3], Step [10800/16565], Loss: 2.4766, Perplexity: 11.9003
# Epoch [1/3], Step [10900/16565], Loss: 2.2606, Perplexity: 9.58907
# Epoch [1/3], Step [11000/16565], Loss: 2.0909, Perplexity: 8.09217
# Epoch [1/3], Step [11100/16565], Loss: 2.4845, Perplexity: 11.9957
# Epoch [1/3], Step [11200/16565], Loss: 2.2273, Perplexity: 9.27492
# Epoch [1/3], Step [11300/16565], Loss: 2.2249, Perplexity: 9.25280
# Epoch [1/3], Step [11400/16565], Loss: 2.3815, Perplexity: 10.8209
# Epoch [1/3], Step [11500/16565], Loss: 2.9956, Perplexity: 19.9972
# Epoch [1/3], Step [11600/16565], Loss: 2.2111, Perplexity: 9.12566
# Epoch [1/3], Step [11700/16565], Loss: 2.1340, Perplexity: 8.44898
# Epoch [1/3], Step [11800/16565], Loss: 2.1646, Perplexity: 8.71091
# Epoch [1/3], Step [11900/16565], Loss: 2.2590, Perplexity: 9.57340
# Epoch [1/3], Step [12000/16565], Loss: 1.7118, Perplexity: 5.53927
# Epoch [1/3], Step [12100/16565], Loss: 3.0581, Perplexity: 21.2878
# Epoch [1/3], Step [12200/16565], Loss: 2.4716, Perplexity: 11.8419
# Epoch [1/3], Step [12300/16565], Loss: 2.2598, Perplexity: 9.58078
# Epoch [1/3], Step [12400/16565], Loss: 2.1409, Perplexity: 8.50699
# Epoch [1/3], Step [12500/16565], Loss: 2.3649, Perplexity: 10.6431
# Epoch [1/3], Step [12600/16565], Loss: 2.2476, Perplexity: 9.46507
# Epoch [1/3], Step [12700/16565], Loss: 2.1509, Perplexity: 8.59255
# Epoch [1/3], Step [12800/16565], Loss: 2.0336, Perplexity: 7.64159
# Epoch [1/3], Step [12900/16565], Loss: 2.3668, Perplexity: 10.6634
# Epoch [1/3], Step [13000/16565], Loss: 2.3000, Perplexity: 9.97421
# Epoch [1/3], Step [13100/16565], Loss: 2.4983, Perplexity: 12.1613
# Epoch [1/3], Step [13200/16565], Loss: 2.2314, Perplexity: 9.313045
# Epoch [1/3], Step [13300/16565], Loss: 2.4857, Perplexity: 12.0097
# Epoch [1/3], Step [13400/16565], Loss: 2.0321, Perplexity: 7.63040
# Epoch [1/3], Step [13500/16565], Loss: 2.4464, Perplexity: 11.5469
# Epoch [1/3], Step [13600/16565], Loss: 2.3905, Perplexity: 10.9190
# Epoch [1/3], Step [13700/16565], Loss: 2.1989, Perplexity: 9.01526
# Epoch [1/3], Step [13800/16565], Loss: 2.1724, Perplexity: 8.77921
# Epoch [1/3], Step [13900/16565], Loss: 1.9417, Perplexity: 6.97043
# Epoch [1/3], Step [14000/16565], Loss: 2.1924, Perplexity: 8.95646
# Epoch [1/3], Step [14100/16565], Loss: 2.2635, Perplexity: 9.61654
# Epoch [1/3], Step [14200/16565], Loss: 1.9971, Perplexity: 7.36801
# Epoch [1/3], Step [14300/16565], Loss: 2.3831, Perplexity: 10.8380
# Epoch [1/3], Step [14400/16565], Loss: 4.3864, Perplexity: 80.3479
# Epoch [1/3], Step [14500/16565], Loss: 2.1069, Perplexity: 8.22295
# Epoch [1/3], Step [14600/16565], Loss: 2.1473, Perplexity: 8.56155
# Epoch [1/3], Step [14700/16565], Loss: 2.6508, Perplexity: 14.1652
# Epoch [1/3], Step [14800/16565], Loss: 2.3218, Perplexity: 10.1937
# Epoch [1/3], Step [14900/16565], Loss: 2.1713, Perplexity: 8.76992
# Epoch [1/3], Step [15000/16565], Loss: 2.5548, Perplexity: 12.8685
# Epoch [1/3], Step [15100/16565], Loss: 2.0302, Perplexity: 7.61554
# Epoch [1/3], Step [15200/16565], Loss: 2.2847, Perplexity: 9.82247
# Epoch [1/3], Step [15300/16565], Loss: 2.3774, Perplexity: 10.7766
# Epoch [1/3], Step [15400/16565], Loss: 2.2035, Perplexity: 9.05708
# Epoch [1/3], Step [15500/16565], Loss: 2.2784, Perplexity: 9.76113
# Epoch [1/3], Step [15600/16565], Loss: 2.1581, Perplexity: 8.65505
# Epoch [1/3], Step [15700/16565], Loss: 1.9822, Perplexity: 7.25840
# Epoch [1/3], Step [15800/16565], Loss: 1.9672, Perplexity: 7.15059
# Epoch [1/3], Step [15900/16565], Loss: 2.4675, Perplexity: 11.7929
# Epoch [1/3], Step [16000/16565], Loss: 2.2397, Perplexity: 9.39081
# Epoch [1/3], Step [16100/16565], Loss: 2.5499, Perplexity: 12.8063
# Epoch [1/3], Step [16200/16565], Loss: 2.5676, Perplexity: 13.0344
# Epoch [1/3], Step [16400/16565], Loss: 1.8163, Perplexity: 6.14922
# Epoch [1/3], Step [16500/16565], Loss: 2.0134, Perplexity: 7.48868
# Epoch [2/3], Step [100/16565], Loss: 2.5386, Perplexity: 12.661604
# Epoch [2/3], Step [200/16565], Loss: 1.9637, Perplexity: 7.12551
# Epoch [2/3], Step [300/16565], Loss: 2.2706, Perplexity: 9.68558
# Epoch [2/3], Step [400/16565], Loss: 2.2264, Perplexity: 9.26694
# Epoch [2/3], Step [500/16565], Loss: 2.1114, Perplexity: 8.26004
# Epoch [2/3], Step [600/16565], Loss: 2.3960, Perplexity: 10.9797
# Epoch [2/3], Step [700/16565], Loss: 1.9940, Perplexity: 7.34488
# Epoch [2/3], Step [800/16565], Loss: 2.4586, Perplexity: 11.6883
# Epoch [2/3], Step [900/16565], Loss: 1.9791, Perplexity: 7.23635
# Epoch [2/3], Step [1000/16565], Loss: 2.2287, Perplexity: 9.2875
# Epoch [2/3], Step [1100/16565], Loss: 2.1472, Perplexity: 8.56064
# Epoch [2/3], Step [1200/16565], Loss: 2.0896, Perplexity: 8.08173
# Epoch [2/3], Step [1300/16565], Loss: 3.2424, Perplexity: 25.5949
# Epoch [2/3], Step [1400/16565], Loss: 1.9939, Perplexity: 7.344178
# Epoch [2/3], Step [1500/16565], Loss: 1.9792, Perplexity: 7.23722
# Epoch [2/3], Step [1600/16565], Loss: 2.1521, Perplexity: 8.60324
# Epoch [2/3], Step [1700/16565], Loss: 2.0629, Perplexity: 7.86842
# Epoch [2/3], Step [1800/16565], Loss: 2.8147, Perplexity: 16.6878
# Epoch [2/3], Step [1900/16565], Loss: 2.0499, Perplexity: 7.76750
# Epoch [2/3], Step [2000/16565], Loss: 2.2118, Perplexity: 9.13221
# Epoch [2/3], Step [2100/16565], Loss: 2.0299, Perplexity: 7.61347
# Epoch [2/3], Step [2200/16565], Loss: 2.0686, Perplexity: 7.91384
# Epoch [2/3], Step [2300/16565], Loss: 2.0384, Perplexity: 7.67845
# Epoch [2/3], Step [2400/16565], Loss: 2.3137, Perplexity: 10.1117
# Epoch [2/3], Step [2500/16565], Loss: 1.8360, Perplexity: 6.27136
# Epoch [2/3], Step [2600/16565], Loss: 2.2226, Perplexity: 9.23168
# Epoch [2/3], Step [2700/16565], Loss: 2.5019, Perplexity: 12.2053
# Epoch [2/3], Step [2800/16565], Loss: 2.3079, Perplexity: 10.0531
# Epoch [2/3], Step [2900/16565], Loss: 1.9158, Perplexity: 6.79234
# Epoch [2/3], Step [3000/16565], Loss: 2.5993, Perplexity: 13.4545
# Epoch [2/3], Step [3100/16565], Loss: 2.2036, Perplexity: 9.05796
# Epoch [2/3], Step [3200/16565], Loss: 2.4559, Perplexity: 11.6566
# Epoch [2/3], Step [3300/16565], Loss: 2.2725, Perplexity: 9.70401
# Epoch [2/3], Step [3400/16565], Loss: 2.5920, Perplexity: 13.3571
# Epoch [2/3], Step [3500/16565], Loss: 1.9898, Perplexity: 7.31433
# Epoch [2/3], Step [3600/16565], Loss: 2.1820, Perplexity: 8.86445
# Epoch [2/3], Step [3700/16565], Loss: 2.2122, Perplexity: 9.135666
# Epoch [2/3], Step [3800/16565], Loss: 2.1209, Perplexity: 8.33873
# Epoch [2/3], Step [3900/16565], Loss: 2.2833, Perplexity: 9.80892
# Epoch [2/3], Step [4000/16565], Loss: 2.3703, Perplexity: 10.7008
# Epoch [2/3], Step [4100/16565], Loss: 2.0702, Perplexity: 7.92672
# Epoch [2/3], Step [4200/16565], Loss: 1.8915, Perplexity: 6.62941
# Epoch [2/3], Step [4300/16565], Loss: 2.2234, Perplexity: 9.23836
# Epoch [2/3], Step [4500/16565], Loss: 2.2675, Perplexity: 9.65534
# Epoch [2/3], Step [4600/16565], Loss: 2.0366, Perplexity: 7.66475
# Epoch [2/3], Step [4700/16565], Loss: 2.1000, Perplexity: 8.16592
# Epoch [2/3], Step [4800/16565], Loss: 1.8291, Perplexity: 6.22819
# Epoch [2/3], Step [4900/16565], Loss: 2.4783, Perplexity: 11.9207
# Epoch [2/3], Step [5000/16565], Loss: 2.1369, Perplexity: 8.47350
# Epoch [2/3], Step [5100/16565], Loss: 2.4099, Perplexity: 11.1327
# Epoch [2/3], Step [5200/16565], Loss: 2.0384, Perplexity: 7.67848
# Epoch [2/3], Step [5300/16565], Loss: 2.1283, Perplexity: 8.40036
# Epoch [2/3], Step [5400/16565], Loss: 2.6669, Perplexity: 14.3953
# Epoch [2/3], Step [5500/16565], Loss: 2.3384, Perplexity: 10.3649
# Epoch [2/3], Step [5600/16565], Loss: 2.4595, Perplexity: 11.6994
# Epoch [2/3], Step [5700/16565], Loss: 2.6540, Perplexity: 14.2112
# Epoch [2/3], Step [5800/16565], Loss: 2.1972, Perplexity: 8.99998
# Epoch [2/3], Step [5900/16565], Loss: 2.1708, Perplexity: 8.76507
# Epoch [2/3], Step [6000/16565], Loss: 2.0228, Perplexity: 7.55929
# Epoch [2/3], Step [6100/16565], Loss: 2.0287, Perplexity: 7.60398
# Epoch [2/3], Step [6200/16565], Loss: 1.9184, Perplexity: 6.81017
# Epoch [2/3], Step [6300/16565], Loss: 2.1226, Perplexity: 8.35290
# Epoch [2/3], Step [6400/16565], Loss: 2.3218, Perplexity: 10.1936
# Epoch [2/3], Step [6500/16565], Loss: 1.7989, Perplexity: 6.04335
# Epoch [2/3], Step [6600/16565], Loss: 1.8105, Perplexity: 6.11349
# Epoch [2/3], Step [6700/16565], Loss: 2.7644, Perplexity: 15.8694
# Epoch [2/3], Step [6800/16565], Loss: 2.5415, Perplexity: 12.6986
# Epoch [2/3], Step [6900/16565], Loss: 2.6254, Perplexity: 13.8103
# Epoch [2/3], Step [7000/16565], Loss: 2.2292, Perplexity: 9.29240
# Epoch [2/3], Step [7100/16565], Loss: 2.3559, Perplexity: 10.5476
# Epoch [2/3], Step [7200/16565], Loss: 2.1752, Perplexity: 8.80411
# Epoch [2/3], Step [7300/16565], Loss: 2.1108, Perplexity: 8.25479
# Epoch [2/3], Step [7400/16565], Loss: 2.0816, Perplexity: 8.01755
# Epoch [2/3], Step [7500/16565], Loss: 1.8107, Perplexity: 6.11466
# Epoch [2/3], Step [7600/16565], Loss: 1.9851, Perplexity: 7.27953
# Epoch [2/3], Step [7700/16565], Loss: 2.0349, Perplexity: 7.65159
# Epoch [2/3], Step [7800/16565], Loss: 2.2650, Perplexity: 9.63079
# Epoch [2/3], Step [7900/16565], Loss: 2.5292, Perplexity: 12.5430
# Epoch [2/3], Step [8000/16565], Loss: 2.5096, Perplexity: 12.2999
# Epoch [2/3], Step [8100/16565], Loss: 2.2312, Perplexity: 9.31093
# Epoch [2/3], Step [8200/16565], Loss: 2.3605, Perplexity: 10.5960
# Epoch [2/3], Step [8300/16565], Loss: 2.3675, Perplexity: 10.6708
# Epoch [2/3], Step [8400/16565], Loss: 2.0998, Perplexity: 8.16466
# Epoch [2/3], Step [8500/16565], Loss: 2.1686, Perplexity: 8.74583
# Epoch [2/3], Step [8600/16565], Loss: 1.6601, Perplexity: 5.25969
# Epoch [2/3], Step [8900/16565], Loss: 2.2349, Perplexity: 9.345794
# Epoch [2/3], Step [9000/16565], Loss: 2.1178, Perplexity: 8.31299
# Epoch [2/3], Step [9100/16565], Loss: 2.3866, Perplexity: 10.8767
# Epoch [2/3], Step [9200/16565], Loss: 1.9349, Perplexity: 6.92338
# Epoch [2/3], Step [9300/16565], Loss: 2.4836, Perplexity: 11.9842
# Epoch [2/3], Step [9400/16565], Loss: 1.9610, Perplexity: 7.10651
# Epoch [2/3], Step [9500/16565], Loss: 2.1317, Perplexity: 8.42965
# Epoch [2/3], Step [9600/16565], Loss: 1.8525, Perplexity: 6.37558
# Epoch [2/3], Step [9700/16565], Loss: 2.0015, Perplexity: 7.40035
# Epoch [2/3], Step [9800/16565], Loss: 1.8310, Perplexity: 6.24014
# Epoch [2/3], Step [9900/16565], Loss: 2.5016, Perplexity: 12.2026
# Epoch [2/3], Step [10000/16565], Loss: 2.1732, Perplexity: 8.7862
# Epoch [2/3], Step [10100/16565], Loss: 1.9854, Perplexity: 7.28220
# Epoch [2/3], Step [10200/16565], Loss: 2.3147, Perplexity: 10.1223
# Epoch [2/3], Step [10300/16565], Loss: 2.1173, Perplexity: 8.30859
# Epoch [2/3], Step [10400/16565], Loss: 2.3440, Perplexity: 10.4227
# Epoch [2/3], Step [10500/16565], Loss: 2.6388, Perplexity: 13.9957
# Epoch [2/3], Step [10600/16565], Loss: 2.0641, Perplexity: 7.87848
# Epoch [2/3], Step [10700/16565], Loss: 1.7514, Perplexity: 5.76288
# Epoch [2/3], Step [10800/16565], Loss: 1.9226, Perplexity: 6.83853
# Epoch [2/3], Step [10900/16565], Loss: 2.3921, Perplexity: 10.9367
# Epoch [2/3], Step [11000/16565], Loss: 2.0263, Perplexity: 7.58619
# Epoch [2/3], Step [11100/16565], Loss: 2.2224, Perplexity: 9.229723
# Epoch [2/3], Step [11200/16565], Loss: 2.0048, Perplexity: 7.42472
# Epoch [2/3], Step [11300/16565], Loss: 2.1472, Perplexity: 8.56104
# Epoch [2/3], Step [11400/16565], Loss: 2.0582, Perplexity: 7.83179
# Epoch [2/3], Step [11500/16565], Loss: 2.4073, Perplexity: 11.1042
# Epoch [2/3], Step [11600/16565], Loss: 2.7089, Perplexity: 15.0123
# Epoch [2/3], Step [11700/16565], Loss: 1.8930, Perplexity: 6.63958
# Epoch [2/3], Step [11800/16565], Loss: 2.3396, Perplexity: 10.3774
# Epoch [2/3], Step [11900/16565], Loss: 2.0422, Perplexity: 7.70787
# Epoch [2/3], Step [12000/16565], Loss: 2.2322, Perplexity: 9.32040
# Epoch [2/3], Step [12100/16565], Loss: 2.2229, Perplexity: 9.23447
# Epoch [2/3], Step [12200/16565], Loss: 2.0304, Perplexity: 7.61682
# Epoch [2/3], Step [12300/16565], Loss: 1.8482, Perplexity: 6.34843
# Epoch [2/3], Step [12400/16565], Loss: 2.3312, Perplexity: 10.2903
# Epoch [2/3], Step [12500/16565], Loss: 3.0265, Perplexity: 20.6243
# Epoch [2/3], Step [12600/16565], Loss: 2.1145, Perplexity: 8.28517
# Epoch [2/3], Step [12700/16565], Loss: 2.1070, Perplexity: 8.22370
# Epoch [2/3], Step [12800/16565], Loss: 2.8601, Perplexity: 17.4631
# Epoch [2/3], Step [12900/16565], Loss: 2.4102, Perplexity: 11.1366
# Epoch [2/3], Step [13000/16565], Loss: 2.2310, Perplexity: 9.30907
# Epoch [2/3], Step [13100/16565], Loss: 2.0792, Perplexity: 7.99821
# Epoch [2/3], Step [13200/16565], Loss: 1.9357, Perplexity: 6.92879
# Epoch [2/3], Step [13300/16565], Loss: 2.0396, Perplexity: 7.68730
# Epoch [2/3], Step [13400/16565], Loss: 1.9787, Perplexity: 7.23344
# Epoch [2/3], Step [13500/16565], Loss: 2.2424, Perplexity: 9.41643
# Epoch [2/3], Step [13600/16565], Loss: 2.1373, Perplexity: 8.47635
# Epoch [2/3], Step [13700/16565], Loss: 2.1174, Perplexity: 8.30941
# Epoch [2/3], Step [13800/16565], Loss: 2.0738, Perplexity: 7.95463
# Epoch [2/3], Step [13900/16565], Loss: 2.2802, Perplexity: 9.77902
# Epoch [2/3], Step [14000/16565], Loss: 1.8659, Perplexity: 6.46163
# Epoch [2/3], Step [14100/16565], Loss: 2.5027, Perplexity: 12.2155
# Epoch [2/3], Step [14200/16565], Loss: 2.1197, Perplexity: 8.32851
# Epoch [2/3], Step [14300/16565], Loss: 1.9863, Perplexity: 7.288247
# Epoch [2/3], Step [14400/16565], Loss: 2.0354, Perplexity: 7.65504
# Epoch [2/3], Step [14500/16565], Loss: 2.1262, Perplexity: 8.38255
# Epoch [2/3], Step [14600/16565], Loss: 2.2205, Perplexity: 9.21201
# Epoch [2/3], Step [14700/16565], Loss: 2.3341, Perplexity: 10.3202
# Epoch [2/3], Step [14800/16565], Loss: 2.4175, Perplexity: 11.2181
# Epoch [2/3], Step [14900/16565], Loss: 2.0018, Perplexity: 7.40229
# Epoch [2/3], Step [15000/16565], Loss: 2.3050, Perplexity: 10.0241
# Epoch [2/3], Step [15100/16565], Loss: 2.1661, Perplexity: 8.72380
# Epoch [2/3], Step [15200/16565], Loss: 2.2237, Perplexity: 9.24135
# Epoch [2/3], Step [15300/16565], Loss: 2.2925, Perplexity: 9.89970
# Epoch [2/3], Step [15400/16565], Loss: 2.1222, Perplexity: 8.34975
# Epoch [2/3], Step [15500/16565], Loss: 2.3354, Perplexity: 10.3339
# Epoch [2/3], Step [15600/16565], Loss: 1.9341, Perplexity: 6.91787
# Epoch [2/3], Step [15700/16565], Loss: 2.0271, Perplexity: 7.59212
# Epoch [2/3], Step [15800/16565], Loss: 2.2897, Perplexity: 9.87234
# Epoch [2/3], Step [15900/16565], Loss: 2.6835, Perplexity: 14.6363
# Epoch [2/3], Step [16000/16565], Loss: 2.3410, Perplexity: 10.3915
# Epoch [2/3], Step [16100/16565], Loss: 2.1602, Perplexity: 8.67256
# Epoch [2/3], Step [16200/16565], Loss: 2.1498, Perplexity: 8.58311
# Epoch [2/3], Step [16300/16565], Loss: 2.7196, Perplexity: 15.1736
# Epoch [2/3], Step [16400/16565], Loss: 2.1201, Perplexity: 8.33162
# Epoch [2/3], Step [16500/16565], Loss: 2.1045, Perplexity: 8.20298
# Epoch [3/3], Step [100/16565], Loss: 2.0689, Perplexity: 7.9163432
# Epoch [3/3], Step [200/16565], Loss: 2.4885, Perplexity: 12.0434
# Epoch [3/3], Step [300/16565], Loss: 2.1316, Perplexity: 8.42879
# Epoch [3/3], Step [400/16565], Loss: 1.8527, Perplexity: 6.37739
# Epoch [3/3], Step [500/16565], Loss: 2.1870, Perplexity: 8.90818
# Epoch [3/3], Step [600/16565], Loss: 2.3937, Perplexity: 10.9535
# Epoch [3/3], Step [700/16565], Loss: 1.9107, Perplexity: 6.75791
# Epoch [3/3], Step [800/16565], Loss: 2.1849, Perplexity: 8.89007
# Epoch [3/3], Step [900/16565], Loss: 2.5959, Perplexity: 13.4088
# Epoch [3/3], Step [1000/16565], Loss: 1.7684, Perplexity: 5.8615
# Epoch [3/3], Step [1100/16565], Loss: 1.8060, Perplexity: 6.08627
# Epoch [3/3], Step [1200/16565], Loss: 2.2158, Perplexity: 9.16911
# Epoch [3/3], Step [1300/16565], Loss: 2.0544, Perplexity: 7.80216
# Epoch [3/3], Step [1400/16565], Loss: 2.1159, Perplexity: 8.29701
# Epoch [3/3], Step [1500/16565], Loss: 2.1835, Perplexity: 8.87742
# Epoch [3/3], Step [1600/16565], Loss: 1.9977, Perplexity: 7.37183
# Epoch [3/3], Step [1700/16565], Loss: 2.4088, Perplexity: 11.1201
# Epoch [3/3], Step [1800/16565], Loss: 1.7322, Perplexity: 5.65293
# Epoch [3/3], Step [1900/16565], Loss: 1.8306, Perplexity: 6.23782
# Epoch [3/3], Step [2000/16565], Loss: 2.0939, Perplexity: 8.11630
# Epoch [3/3], Step [2100/16565], Loss: 2.0916, Perplexity: 8.09783
# Epoch [3/3], Step [2200/16565], Loss: 2.1653, Perplexity: 8.71745
# Epoch [3/3], Step [2300/16565], Loss: 2.8103, Perplexity: 16.6150
# Epoch [3/3], Step [2400/16565], Loss: 2.0684, Perplexity: 7.91200
# Epoch [3/3], Step [2500/16565], Loss: 2.1949, Perplexity: 8.97925
# Epoch [3/3], Step [2600/16565], Loss: 2.0410, Perplexity: 7.69828
# Epoch [3/3], Step [2700/16565], Loss: 2.0218, Perplexity: 7.55230
# Epoch [3/3], Step [2800/16565], Loss: 1.9217, Perplexity: 6.83241
# Epoch [3/3], Step [2900/16565], Loss: 2.2188, Perplexity: 9.19601
# Epoch [3/3], Step [3000/16565], Loss: 2.0591, Perplexity: 7.83874
# Epoch [3/3], Step [3100/16565], Loss: 2.5392, Perplexity: 12.6699
# Epoch [3/3], Step [3200/16565], Loss: 2.1021, Perplexity: 8.18325
# Epoch [3/3], Step [3300/16565], Loss: 2.1751, Perplexity: 8.80293
# Epoch [3/3], Step [3400/16565], Loss: 2.5293, Perplexity: 12.5447
# Epoch [3/3], Step [3500/16565], Loss: 2.2113, Perplexity: 9.12763
# Epoch [3/3], Step [3600/16565], Loss: 1.8501, Perplexity: 6.36015
# Epoch [3/3], Step [3700/16565], Loss: 1.7993, Perplexity: 6.04525
# Epoch [3/3], Step [3800/16565], Loss: 2.0321, Perplexity: 7.62982
# Epoch [3/3], Step [3900/16565], Loss: 2.2398, Perplexity: 9.39127
# Epoch [3/3], Step [4000/16565], Loss: 2.2390, Perplexity: 9.38432
# Epoch [3/3], Step [4100/16565], Loss: 1.9029, Perplexity: 6.70558
# Epoch [3/3], Step [4200/16565], Loss: 2.2133, Perplexity: 9.14628
# Epoch [3/3], Step [4300/16565], Loss: 1.7604, Perplexity: 5.81506
# Epoch [3/3], Step [4400/16565], Loss: 2.2413, Perplexity: 9.40543
# Epoch [3/3], Step [4500/16565], Loss: 2.5464, Perplexity: 12.7615
# Epoch [3/3], Step [4600/16565], Loss: 2.3379, Perplexity: 10.3599
# Epoch [3/3], Step [4700/16565], Loss: 2.0477, Perplexity: 7.75033
# Epoch [3/3], Step [4800/16565], Loss: 2.2578, Perplexity: 9.56225
# Epoch [3/3], Step [4900/16565], Loss: 2.3130, Perplexity: 10.1048
# Epoch [3/3], Step [5000/16565], Loss: 2.4095, Perplexity: 11.1289
# Epoch [3/3], Step [5100/16565], Loss: 2.0967, Perplexity: 8.13942
# Epoch [3/3], Step [5200/16565], Loss: 2.1654, Perplexity: 8.71830
# Epoch [3/3], Step [5300/16565], Loss: 2.0108, Perplexity: 7.46948
# Epoch [3/3], Step [5400/16565], Loss: 1.9693, Perplexity: 7.16545
# Epoch [3/3], Step [5500/16565], Loss: 2.2775, Perplexity: 9.75184
# Epoch [3/3], Step [5600/16565], Loss: 2.2931, Perplexity: 9.90577
# Epoch [3/3], Step [5700/16565], Loss: 2.3265, Perplexity: 10.2424
# Epoch [3/3], Step [5800/16565], Loss: 2.5145, Perplexity: 12.3600
# Epoch [3/3], Step [5900/16565], Loss: 1.9937, Perplexity: 7.34288
# Epoch [3/3], Step [6000/16565], Loss: 1.8645, Perplexity: 6.45251
# Epoch [3/3], Step [6100/16565], Loss: 1.9448, Perplexity: 6.99213
# Epoch [3/3], Step [6200/16565], Loss: 2.0547, Perplexity: 7.80421
# Epoch [3/3], Step [6300/16565], Loss: 2.0226, Perplexity: 7.55839
# Epoch [3/3], Step [6400/16565], Loss: 2.1404, Perplexity: 8.50304
# Epoch [3/3], Step [6500/16565], Loss: 2.2676, Perplexity: 9.65576
# Epoch [3/3], Step [6600/16565], Loss: 1.8257, Perplexity: 6.20710
# Epoch [3/3], Step [6700/16565], Loss: 2.0837, Perplexity: 8.03445
# Epoch [3/3], Step [6800/16565], Loss: 2.1058, Perplexity: 8.21401
# Epoch [3/3], Step [6900/16565], Loss: 2.0918, Perplexity: 8.09943
# Epoch [3/3], Step [7000/16565], Loss: 2.0899, Perplexity: 8.08410
# Epoch [3/3], Step [7100/16565], Loss: 2.3778, Perplexity: 10.7809
# Epoch [3/3], Step [7200/16565], Loss: 1.8468, Perplexity: 6.33956
# Epoch [3/3], Step [7300/16565], Loss: 2.2380, Perplexity: 9.37485
# Epoch [3/3], Step [7400/16565], Loss: 1.9698, Perplexity: 7.16909
# Epoch [3/3], Step [7500/16565], Loss: 1.9935, Perplexity: 7.34153
# Epoch [3/3], Step [7600/16565], Loss: 2.2981, Perplexity: 9.95561
# Epoch [3/3], Step [7700/16565], Loss: 1.8158, Perplexity: 6.14593
# Epoch [3/3], Step [7800/16565], Loss: 2.2387, Perplexity: 9.38144
# Epoch [3/3], Step [7900/16565], Loss: 2.1127, Perplexity: 8.27021
# Epoch [3/3], Step [8000/16565], Loss: 2.5721, Perplexity: 13.0939
# Epoch [3/3], Step [8100/16565], Loss: 2.3053, Perplexity: 10.0273
# Epoch [3/3], Step [8200/16565], Loss: 1.9179, Perplexity: 6.80668
# Epoch [3/3], Step [8300/16565], Loss: 1.7561, Perplexity: 5.79016
# Epoch [3/3], Step [8400/16565], Loss: 2.0378, Perplexity: 7.67364
# Epoch [3/3], Step [8500/16565], Loss: 2.1144, Perplexity: 8.28440
# Epoch [3/3], Step [8600/16565], Loss: 1.9513, Perplexity: 7.03809
# Epoch [3/3], Step [8700/16565], Loss: 2.1802, Perplexity: 8.84826
# Epoch [3/3], Step [8800/16565], Loss: 2.1951, Perplexity: 8.98104
# Epoch [3/3], Step [8900/16565], Loss: 1.9525, Perplexity: 7.04646
# Epoch [3/3], Step [9000/16565], Loss: 1.9823, Perplexity: 7.25929
# Epoch [3/3], Step [9100/16565], Loss: 2.0443, Perplexity: 7.72358
# Epoch [3/3], Step [9200/16565], Loss: 1.9991, Perplexity: 7.38237
# Epoch [3/3], Step [9300/16565], Loss: 2.1148, Perplexity: 8.28814
# Epoch [3/3], Step [9400/16565], Loss: 2.1468, Perplexity: 8.55748
# Epoch [3/3], Step [9500/16565], Loss: 2.0963, Perplexity: 8.13621
# Epoch [3/3], Step [9600/16565], Loss: 1.9156, Perplexity: 6.79119
# Epoch [3/3], Step [9700/16565], Loss: 1.9627, Perplexity: 7.11853
# Epoch [3/3], Step [9800/16565], Loss: 2.0879, Perplexity: 8.06795
# Epoch [3/3], Step [9900/16565], Loss: 1.8597, Perplexity: 6.42166
# Epoch [3/3], Step [10000/16565], Loss: 2.6965, Perplexity: 14.8275
# Epoch [3/3], Step [10100/16565], Loss: 2.4820, Perplexity: 11.9658
# Epoch [3/3], Step [10200/16565], Loss: 2.1104, Perplexity: 8.25145
# Epoch [3/3], Step [10300/16565], Loss: 2.0458, Perplexity: 7.73574
# Epoch [3/3], Step [10400/16565], Loss: 2.0144, Perplexity: 7.49650
# Epoch [3/3], Step [10500/16565], Loss: 2.1181, Perplexity: 8.31547
# Epoch [3/3], Step [10600/16565], Loss: 1.8094, Perplexity: 6.10667
# Epoch [3/3], Step [10700/16565], Loss: 2.0862, Perplexity: 8.05419
# Epoch [3/3], Step [10800/16565], Loss: 2.0051, Perplexity: 7.42667
# Epoch [3/3], Step [10900/16565], Loss: 1.9969, Perplexity: 7.36625
# Epoch [3/3], Step [11000/16565], Loss: 2.3642, Perplexity: 10.6358
# Epoch [3/3], Step [11100/16565], Loss: 2.4338, Perplexity: 11.4018
# Epoch [3/3], Step [11200/16565], Loss: 2.3587, Perplexity: 10.5774
# Epoch [3/3], Step [11300/16565], Loss: 2.1574, Perplexity: 8.64885
# Epoch [3/3], Step [11400/16565], Loss: 1.8572, Perplexity: 6.40584
# Epoch [3/3], Step [11500/16565], Loss: 2.1721, Perplexity: 8.77690
# Epoch [3/3], Step [11600/16565], Loss: 1.9474, Perplexity: 7.01025
# Epoch [3/3], Step [11700/16565], Loss: 1.7242, Perplexity: 5.60806
# Epoch [3/3], Step [11800/16565], Loss: 2.1541, Perplexity: 8.62015
# Epoch [3/3], Step [11900/16565], Loss: 2.0371, Perplexity: 7.66864
# Epoch [3/3], Step [12000/16565], Loss: 1.8659, Perplexity: 6.46187
# Epoch [3/3], Step [12100/16565], Loss: 1.8648, Perplexity: 6.45454
# Epoch [3/3], Step [12200/16565], Loss: 1.9330, Perplexity: 6.91014
# Epoch [3/3], Step [12300/16565], Loss: 1.9915, Perplexity: 7.32643
# Epoch [3/3], Step [12400/16565], Loss: 2.0398, Perplexity: 7.68926
# Epoch [3/3], Step [12500/16565], Loss: 2.2681, Perplexity: 9.66097
# Epoch [3/3], Step [12600/16565], Loss: 1.8548, Perplexity: 6.39068
# Epoch [3/3], Step [12700/16565], Loss: 2.1365, Perplexity: 8.46976
# Epoch [3/3], Step [12800/16565], Loss: 2.0625, Perplexity: 7.86558
# Epoch [3/3], Step [12900/16565], Loss: 1.9196, Perplexity: 6.81848
# Epoch [3/3], Step [13000/16565], Loss: 1.8480, Perplexity: 6.34729
# Epoch [3/3], Step [13100/16565], Loss: 3.0970, Perplexity: 22.1324
# Epoch [3/3], Step [13200/16565], Loss: 2.2656, Perplexity: 9.63724
# Epoch [3/3], Step [13300/16565], Loss: 2.0275, Perplexity: 7.59508
# Epoch [3/3], Step [13400/16565], Loss: 2.1530, Perplexity: 8.61105
# Epoch [3/3], Step [13500/16565], Loss: 2.0943, Perplexity: 8.11965
# Epoch [3/3], Step [13600/16565], Loss: 1.9698, Perplexity: 7.16947
# Epoch [3/3], Step [13700/16565], Loss: 2.1045, Perplexity: 8.20331
# Epoch [3/3], Step [13800/16565], Loss: 2.1168, Perplexity: 8.30474
# Epoch [3/3], Step [13900/16565], Loss: 2.0906, Perplexity: 8.08994
# Epoch [3/3], Step [14000/16565], Loss: 1.7999, Perplexity: 6.04885
# Epoch [3/3], Step [14100/16565], Loss: 1.9383, Perplexity: 6.94702
# Epoch [3/3], Step [14200/16565], Loss: 1.8583, Perplexity: 6.41282
# Epoch [3/3], Step [14300/16565], Loss: 2.1202, Perplexity: 8.33315
# Epoch [3/3], Step [14400/16565], Loss: 2.1057, Perplexity: 8.21311
# Epoch [3/3], Step [14500/16565], Loss: 1.9809, Perplexity: 7.24936
# Epoch [3/3], Step [14600/16565], Loss: 1.9187, Perplexity: 6.81229
# Epoch [3/3], Step [14700/16565], Loss: 1.9859, Perplexity: 7.28545
# Epoch [3/3], Step [14800/16565], Loss: 1.9880, Perplexity: 7.30112
# Epoch [3/3], Step [14900/16565], Loss: 2.0126, Perplexity: 7.48249
# Epoch [3/3], Step [15000/16565], Loss: 2.3017, Perplexity: 9.99114
# Epoch [3/3], Step [15100/16565], Loss: 2.0951, Perplexity: 8.12593
# Epoch [3/3], Step [15200/16565], Loss: 2.3086, Perplexity: 10.0601
# Epoch [3/3], Step [15300/16565], Loss: 2.7586, Perplexity: 15.7779
# Epoch [3/3], Step [15400/16565], Loss: 2.2477, Perplexity: 9.46578
# Epoch [3/3], Step [15500/16565], Loss: 1.9125, Perplexity: 6.76980
# Epoch [3/3], Step [15600/16565], Loss: 2.0679, Perplexity: 7.90816
# Epoch [3/3], Step [15700/16565], Loss: 1.9927, Perplexity: 7.33501
# Epoch [3/3], Step [15800/16565], Loss: 1.9866, Perplexity: 7.29051
# Epoch [3/3], Step [15900/16565], Loss: 1.9497, Perplexity: 7.02649
# Epoch [3/3], Step [16000/16565], Loss: 2.0585, Perplexity: 7.83443
# Epoch [3/3], Step [16100/16565], Loss: 2.0712, Perplexity: 7.93473
# Epoch [3/3], Step [16200/16565], Loss: 2.0605, Perplexity: 7.84996
# Epoch [3/3], Step [16300/16565], Loss: 2.0118, Perplexity: 7.47652
# Epoch [3/3], Step [16400/16565], Loss: 2.1193, Perplexity: 8.32560
# Epoch [3/3], Step [16500/16565], Loss: 1.8824, Perplexity: 6.56955
# Epoch [3/3], Step [16565/16565], Loss: 1.9985, Perplexity: 7.37800

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
